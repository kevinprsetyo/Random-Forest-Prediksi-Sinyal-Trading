# %% [markdown]
# # Prediksi & Backtest Saham Sektor Kesehatan (Periode 3 Hari)
#
# Notebook ini melakukan:
# 1. **Download data** harga saham untuk 8 ticker sektor kesehatan (IDX).
# 2. **Exploratory Data Analysis (EDA)** untuk memahami karakteristik data sebelum modeling.
# 3. **Feature Engineering** (RSI, TEMA, Bollinger Band Width, Volume Relatif, Momentum).
# 4. **Labeling** sinyal Buy/Hold/Sell berdasarkan return 3 hari ke depan.
# 5. **Modeling** menggunakan Random Forest per ticker (parameter sudah di-tuning sebelumnya).
# 6. **Backtesting** strategi menggunakan library `backtesting`.
# 7. **Evaluasi** menggunakan confusion matrix & ringkasan performa.
#
# Setiap tahapan dipisah menjadi cell tersendiri agar mudah dijalankan dan dimodifikasi satu per satu di Google Colab.

# %% [markdown]
# ## 1. Instalasi Library
#
# Jalankan cell ini terlebih dahulu jika library belum tersedia di environment Colab (`pandas_ta` dan `backtesting` biasanya belum ter-install secara default).

# %%
# !pip install -q pandas_ta backtesting

# %% [markdown]
# ## 2. Import Library
#
# Mengimpor seluruh library yang dibutuhkan:
# - `yfinance` untuk download data harga saham.
# - `pandas_ta` untuk indikator teknikal (RSI, TEMA, Bollinger Bands).
# - `scikit-learn` untuk model Random Forest & evaluasi.
# - `backtesting` untuk simulasi strategi trading.
# - `matplotlib` & `seaborn` untuk visualisasi (termasuk EDA).

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score
)

from backtesting import Backtest, Strategy

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ## 3. Konfigurasi
#
# Berisi daftar ticker yang akan dianalisis, parameter Random Forest hasil tuning per ticker,
# daftar fitur yang dipakai model, serta parameter labeling (`lookup_periode` dan `threshold`).

# %%
tickers_list = [
    "BMHS.JK",
    "DGNS.JK",
    "HEAL.JK",
    "MIKA.JK",
    "PRDA.JK",
    "PRIM.JK",
    "SAME.JK",
    "SILO.JK"
]

rf_params_map = {
    "SILO.JK": {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50},
    "PRIM.JK": {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50},
    "BMHS.JK": {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100},
    "PRDA.JK": {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 400},
    "HEAL.JK": {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200},
    "SAME.JK": {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 400},
    "DGNS.JK": {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 50},
    "MIKA.JK": {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 400},
}

features = [
    'rsi',
    'tema_20_rel',
    'bb_width',
    'volume_rel',
    'momentum_5',
]

lookup_periode = 3
threshold = 0.015

results = []
testing_cms = []
backtesting_cms = []

labels = ["Sell", "Hold", "Buy"]

# %% [markdown]
# ## 4. Download Data Harga Saham
#
# Mengunduh data harian (OHLCV) untuk semua ticker dari Yahoo Finance, periode 2020-01-01 s/d 2025-12-31.
# Data disimpan dalam dictionary `raw_data` agar bisa dipakai ulang, baik untuk EDA maupun tahap modeling,
# tanpa perlu download berkali-kali.

# %%
raw_data = {}

for ticker in tickers_list:
    print(f"Downloading {ticker} ...")

    data = yf.download(
        ticker,
        start='2020-01-01',
        end='2025-12-31',
        auto_adjust=False,
        multi_level_index=False,
        interval='1d'
    )

    if data.empty:
        print(f"Data kosong untuk {ticker}, skip...")
        continue

    raw_data[ticker] = data

print(f"\nTotal ticker berhasil di-download: {len(raw_data)} dari {len(tickers_list)}")
# Out:
# Downloading BMHS.JK ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading DGNS.JK ...
# Downloading HEAL.JK ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading MIKA.JK ...
# Downloading PRDA.JK ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading PRIM.JK ...
# Downloading SAME.JK ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading SILO.JK ...
#
# Total ticker berhasil di-download: 8 dari 8

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# Sebelum masuk ke feature engineering dan modeling, kita eksplorasi dulu data mentahnya:
# jumlah baris, rentang tanggal, missing value, statistik deskriptif, tren harga, distribusi return,
# serta korelasi antar saham. Tujuannya untuk memastikan data bersih dan memahami karakteristik tiap saham.

# %% [markdown]
# ### 5.1 Ringkasan Umum Data
#
# Menampilkan jumlah baris, rentang tanggal, jumlah missing value, dan harga close terakhir untuk tiap ticker.

# %%
eda_summary = []

for ticker, df in raw_data.items():
    eda_summary.append({
        "Ticker": ticker,
        "Jumlah Baris": len(df),
        "Tanggal Awal": df.index.min().date(),
        "Tanggal Akhir": df.index.max().date(),
        "Missing Values": int(df.isna().sum().sum()),
        "Harga Close Terakhir": df['Close'].iloc[-1]
    })

eda_summary_df = pd.DataFrame(eda_summary)
eda_summary_df
# Out:
#     Ticker  Jumlah Baris Tanggal Awal Tanggal Akhir  Missing Values  \
# 0  BMHS.JK          1082   2021-07-06    2025-12-30               0
# 1  DGNS.JK          1196   2021-01-15    2025-12-30               0
# 2  HEAL.JK          1447   2020-01-02    2025-12-30               0
# 3  MIKA.JK          1447   2020-01-02    2025-12-30               0
# 4  PRDA.JK          1447   2020-01-02    2025-12-30               0
# 5  PRIM.JK          1447   2020-01-02    2025-12-30               0
# 6  SAME.JK          1447   2020-01-02    2025-12-30               0
# 7  SILO.JK          1447   2020-01-02    2025-12-30               0
#
#    Harga Close Terakhir
# 0                 190.0
# 1                 184.0
# 2                1375.0
# 3                2380.0
# 4                2300.0
# 5                  83.0
# 6                 362.0
# 7                2740.0

# %% [markdown]
# ### 5.2 Statistik Deskriptif per Ticker
#
# Melihat sebaran nilai Open, High, Low, Close, dan Volume (mean, std, min, max, kuartil) untuk tiap saham.

# %%
for ticker, df in raw_data.items():
    print(f"\n=== Statistik Deskriptif: {ticker} ===")
    print(df[['Open', 'High', 'Low', 'Close', 'Volume']].describe())
# Out:
# === Statistik Deskriptif: BMHS.JK ===
#               Open         High          Low        Close        Volume
# count  1082.000000  1082.000000  1082.000000  1082.000000  1.082000e+03
# mean    446.178373   454.849353   434.058226   443.789279  1.124015e+07
# std     244.809225   250.531742   238.243129   244.577315  4.131512e+07
# min     149.000000   151.000000   143.000000   147.000000  0.000000e+00
# 25%     278.500000   288.000000   266.500000   276.000000  5.650000e+05
# 50%     376.000000   380.000000   368.000000   374.000000  1.899500e+06
# 75%     590.000000   595.000000   575.000000   590.000000  9.284475e+06
# max    1155.000000  1200.000000  1090.000000  1145.000000  9.859078e+08
#
# === Statistik Deskriptif: DGNS.JK ===
#               Open         High          Low        Close        Volume
# count  1196.000000  1196.000000  1196.000000  1196.000000  1.196000e+03
# mean    373.668060   385.649666   361.484114   371.351171  8.225050e+06
# std     264.916305   277.135316   256.213886   264.664484  1.483870e+07
# min     128.000000   134.000000   121.000000   129.000000  0.000000e+00
# 25%     199.000000   202.000000   194.000000   198.000000  4.794750e+05
# 50%     266.000000   270.000000   254.000000   260.000000  1.861950e+06
# 75%     461.000000   480.500000   448.500000   460.500000  1.036248e+07
# max    1450.000000  1485.000000  1320.000000  1415.000000  1.699250e+08
#
# === Statistik Deskriptif: HEAL.JK ===
#               Open         High          Low        Close        Volume
# count  1447.000000  1447.000000  1447.000000  1447.000000  1.447000e+03
# mean   1207.515549  1227.381479  1188.201797  1205.201106  1.085309e+07
# std     329.250523   333.069533   324.995577   328.965004  1.477385e+07
# min     370.000000   400.000000   370.000000   380.000000  1.450000e+04
# 25%     990.000000  1000.000000   965.000000   990.000000  2.948000e+06
# 50%    1325.000000  1350.000000  1310.000000  1325.000000  7.230700e+06
# 75%    1460.000000  1482.500000  1440.000000  1460.000000  1.390420e+07
# max    1750.000000  1800.000000  1750.000000  1760.000000  2.716308e+08
#
# === Statistik Deskriptif: MIKA.JK ===
#               Open         High          Low        Close        Volume
# count  1447.000000  1447.000000  1447.000000  1447.000000  1.447000e+03
# mean   2615.725639  2659.426399  2562.681410  2606.848652  1.516678e+07
# std     274.196977   277.885620   268.546619   272.643531  1.059588e+07
# min    1685.000000  1795.000000  1570.000000  1685.000000  3.481000e+05
# 25%    2420.000000  2450.000000  2370.000000  2405.000000  8.513900e+06
# 50%    2620.000000  2670.000000  2580.000000  2610.000000  1.231810e+07
# 75%    2790.000000  2840.000000  2730.000000  2780.000000  2.033740e+07
# max    3270.000000  3400.000000  3170.000000  3270.000000  1.631528e+08
#
# === Statistik Deskriptif: PRDA.JK ===
#               Open          High          Low        Close        Volume
# count  1447.000000   1447.000000  1447.000000  1447.000000  1.447000e+03
# mean   4590.697996   4662.912923  4510.165860  4582.560470  9.837690e+05
# std    1817.157460   1863.300251  1771.713848  1816.729881  1.710358e+06
# min    2330.000000   2350.000000  2290.000000  2300.000000  0.000000e+00
# 25%    3000.000000   3010.000000  2980.000000  2995.000000  1.432000e+05
# 50%    3960.000000   4030.000000  3880.000000  3920.000000  5.632000e+05
# 75%    5950.000000   6025.000000  5850.000000  5950.000000  1.298450e+06
# max    9700.000000  10000.000000  9325.000000  9575.000000  2.467350e+07
#
# === Statistik Deskriptif: PRIM.JK ===
#               Open         High          Low        Close        Volume
# count  1447.000000  1447.000000  1447.000000  1447.000000  1.447000e+03
# mean    183.837595   190.513476   178.067726   182.915688  1.434514e+07
# std     115.512428   120.543156   111.220686   114.554944  5.872019e+07
# min      50.000000    51.000000    50.000000    50.000000  0.000000e+00
# 25%      73.000000    76.000000    71.000000    73.000000  2.467000e+05
# 50%     177.000000   180.000000   174.000000   177.000000  1.949600e+06
# 75%     278.000000   290.000000   268.000000   274.000000  7.144300e+06
# max     585.000000   625.000000   585.000000   625.000000  1.061416e+09
#
# === Statistik Deskriptif: SAME.JK ===
#               Open         High          Low        Close        Volume
# count  1447.000000  1447.000000  1447.000000  1447.000000  1.447000e+03
# mean    302.619017   310.263749   294.642618   301.711812  3.189592e+07
# std     124.416662   127.723111   121.554361   124.199000  9.584969e+07
# min      39.048702    42.302761    39.048702    41.651951  0.000000e+00
# 25%     256.000000   262.000000   250.000000   254.000000  1.121750e+06
# 50%     302.000000   308.000000   294.000000   300.000000  5.024200e+06
# 75%     366.000000   380.000000   358.000000   366.000000  2.471400e+07
# max     705.000000   730.000000   690.000000   705.000000  2.103161e+09
#
# === Statistik Deskriptif: SILO.JK ===
#               Open         High          Low        Close        Volume
# count  1447.000000  1447.000000  1447.000000  1447.000000  1.447000e+03
# mean   1585.720888  1614.242830  1556.259502  1584.852281  3.084374e+06
# std     791.850064   806.647219   776.186904   791.407280  5.600609e+06
# min     527.500000   540.000000   526.250000   532.500000  0.000000e+00
# 25%     995.937500  1005.000000   975.000000   995.000000  7.516500e+05
# 50%    1270.000000  1290.000000  1260.000000  1270.000000  1.747400e+06
# 75%    2290.000000  2330.000000  2220.000000  2280.000000  3.517200e+06
# max    3650.000000  3880.000000  3230.000000  3750.000000  1.379555e+08

# %% [markdown]
# ### 5.3 Visualisasi Tren Harga Close
#
# Plot pergerakan harga Close seluruh ticker dalam satu grid agar mudah dibandingkan sekilas.

# %%
fig, axes = plt.subplots(4, 2, figsize=(16, 18))
axes = axes.flatten()

for ax, (ticker, df) in zip(axes, raw_data.items()):
    ax.plot(df.index, df['Close'], linewidth=1)
    ax.set_title(f"Harga Close - {ticker}")
    ax.set_xlabel("Tanggal")
    ax.set_ylabel("Harga")

plt.suptitle("Tren Harga Close Seluruh Ticker", fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.savefig("eda_price_trend.png", dpi=300)
plt.show()

# %% [markdown]
# ### 5.4 Distribusi Return Harian
#
# Histogram + KDE dari return harian tiap saham untuk melihat volatilitas dan bentuk sebaran (normal/skewed/fat-tail).

# %%
fig, axes = plt.subplots(4, 2, figsize=(16, 18))
axes = axes.flatten()

for ax, (ticker, df) in zip(axes, raw_data.items()):
    daily_return = df['Close'].pct_change().dropna()
    sns.histplot(daily_return, bins=50, kde=True, ax=ax, color='steelblue')
    ax.set_title(f"Distribusi Return Harian - {ticker}")
    ax.set_xlabel("Return Harian")

plt.suptitle("Distribusi Return Harian Seluruh Ticker", fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.savefig("eda_return_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# ### 5.5 Korelasi Harga Antar Saham
#
# Heatmap korelasi harga Close antar ticker. Berguna untuk melihat apakah saham-saham ini bergerak searah
# (misalnya karena satu sektor yang sama) yang berimplikasi pada diversifikasi jika dipakai bersamaan dalam portofolio.

# %%
close_prices = pd.DataFrame({
    ticker: df['Close'] for ticker, df in raw_data.items()
})

corr_matrix = close_prices.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Korelasi Harga Close Antar Saham", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig("eda_correlation_heatmap.png", dpi=300)
plt.show()

# %% [markdown]
# ## 6. Fungsi Feature Engineering & Labeling
#
# Dibuat dalam bentuk fungsi (`add_features` dan `add_label`) agar bisa dipanggil ulang secara konsisten,
# baik saat EDA fitur maupun saat proses modeling per ticker, tanpa duplikasi kode.
#
# Fitur yang dihitung:
# - `rsi`: Relative Strength Index (14 hari)
# - `tema_20_rel`: posisi harga relatif terhadap TEMA 20 hari
# - `bb_width`: lebar Bollinger Band (20, 2 std) relatif terhadap middle band
# - `volume_rel`: volume hari ini relatif terhadap rata-rata volume 20 hari
# - `momentum_5`: return 5 hari terakhir
#
# Label dibuat dari return `lookup_periode` hari ke depan dibandingkan `threshold`:
# - `1` (Buy) jika return masa depan > threshold
# - `-1` (Sell) jika return masa depan < -threshold
# - `0` (Hold) selain itu

# %%
def add_features(df):
    df = df.copy()

    df['rsi'] = ta.rsi(df['Close'], length=14)

    df['tema_20_rel'] = (
        df['Close'] / ta.tema(df['Close'], length=20)
    ) - 1

    bb = ta.bbands(df['Close'], length=20, std=2)
    df['bb_upper'] = bb['BBU_20_2.0']
    df['bb_middle'] = bb['BBM_20_2.0']
    df['bb_lower'] = bb['BBL_20_2.0']

    df['bb_width'] = (
        (df['bb_upper'] - df['bb_lower']) / df['bb_middle']
    )

    df['volume_rel'] = (
        df['Volume'] / df['Volume'].rolling(20).mean()
    )

    df['momentum_5'] = (
        df['Close'] / df['Close'].shift(5)
    ) - 1

    return df


def add_label(df, lookup_periode, threshold):
    df = df.copy()

    df["Future_Return"] = (
        df["Close"].shift(-lookup_periode) / df["Close"]
    ) - 1

    df["Label"] = 0
    df.loc[df["Future_Return"] > threshold, "Label"] = 1
    df.loc[df["Future_Return"] < -threshold, "Label"] = -1

    df = df.drop(columns=['Adj Close', 'Future_Return'], errors='ignore')
    df = df.dropna()

    return df

# %% [markdown]
# ## 7. Terapkan Feature Engineering & Labeling ke Semua Ticker
#
# Hasilnya disimpan di `processed_data` (dictionary per ticker) agar dipakai bersama oleh EDA fitur/label
# maupun tahap modeling, tanpa menghitung ulang.

# %%
processed_data = {}

for ticker, df in raw_data.items():
    df_feat = add_features(df)
    df_feat = add_label(df_feat, lookup_periode, threshold)
    processed_data[ticker] = df_feat

print("Contoh data setelah feature engineering & labeling:")
processed_data[tickers_list[0]].tail()
# Out:
# Contoh data setelah feature engineering & labeling:
#             Close   High    Low   Open   Volume        rsi  tema_20_rel  \
# Date
# 2025-12-22  192.0  197.0  183.0  194.0  7018900  50.128087    -0.045380
# 2025-12-23  193.0  195.0  189.0  192.0  5599600  50.950765    -0.031576
# 2025-12-24  192.0  195.0  188.0  193.0  5125100  50.061437    -0.027798
# 2025-12-29  192.0  195.0  189.0  192.0  3299800  50.061437    -0.020335
# 2025-12-30  190.0  192.0  189.0  192.0  4969400  48.113489    -0.021717
#
#               bb_upper  bb_middle    bb_lower  bb_width  volume_rel  \
# Date
# 2025-12-22  215.285066     201.90  188.514934  0.132591    0.282392
# 2025-12-23  214.762862     201.15  187.537138  0.135350    0.324431
# 2025-12-24  214.984034     200.90  186.815966  0.140209    0.336840
# 2025-12-29  215.172741     200.65  186.127259  0.144757    0.259069
# 2025-12-30  215.466767     200.25  185.033233  0.151978    0.400319
#
#             momentum_5  Label
# Date
# 2025-12-22   -0.040000      0
# 2025-12-23   -0.044554     -1
# 2025-12-24   -0.040000      0
# 2025-12-29   -0.005181      0
# 2025-12-30   -0.020619      0

# %% [markdown]
# ## 8. EDA Fitur & Label
#
# Setelah fitur dan label terbentuk, kita cek lagi sebarannya sebelum masuk ke modeling:
# - Apakah label seimbang antar kelas (Buy/Hold/Sell)?
# - Bagaimana bentuk distribusi tiap fitur di seluruh ticker?

# %% [markdown]
# ### 8.1 Distribusi Label per Ticker
#
# Melihat proporsi Sell/Hold/Buy di tiap saham. Distribusi yang timpang (misalnya Hold mendominasi)
# adalah hal wajar untuk labeling berbasis threshold return, tapi penting diketahui karena
# memengaruhi interpretasi hasil model nantinya (makanya `class_weight="balanced"` dipakai saat training).

# %%
label_counts = []

for ticker, df in processed_data.items():
    counts = df['Label'].value_counts().reindex([-1, 0, 1], fill_value=0)
    label_counts.append({
        "Ticker": ticker,
        "Sell (-1)": counts[-1],
        "Hold (0)": counts[0],
        "Buy (1)": counts[1]
    })

label_counts_df = pd.DataFrame(label_counts).set_index("Ticker")

label_counts_df.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    color=['#e74c3c', '#95a5a6', '#2ecc71']
)
plt.title("Distribusi Label per Ticker", fontsize=14, fontweight='bold')
plt.ylabel("Jumlah Data")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("eda_label_distribution.png", dpi=300)
plt.show()

label_counts_df
# Out:
#          Sell (-1)  Hold (0)  Buy (1)
# Ticker
# BMHS.JK        363       474      226
# DGNS.JK        452       402      323
# HEAL.JK        385       636      407
# MIKA.JK        453       552      423
# PRDA.JK        456       597      375
# PRIM.JK        597       437      394
# SAME.JK        524       452      452
# SILO.JK        403       596      429

# %% [markdown]
# ### 8.2 Distribusi Tiap Fitur (Seluruh Ticker)
#
# KDE plot untuk membandingkan bentuk sebaran tiap fitur antar saham. Berguna untuk mendeteksi
# outlier ekstrem atau fitur yang skalanya sangat berbeda antar ticker.

# %%
fig, axes = plt.subplots(len(features), 1, figsize=(10, 4 * len(features)))

for ax, feat in zip(axes, features):
    for ticker, df in processed_data.items():
        sns.kdeplot(df[feat], ax=ax, label=ticker)
    ax.set_title(f"Distribusi Fitur: {feat}")
    ax.legend(fontsize=8, ncol=2)

plt.tight_layout()
plt.savefig("eda_feature_distribution.png", dpi=300)
plt.show()

# %% [markdown]
# ## 9. Modeling & Backtesting per Ticker
#
# Untuk tiap ticker:
# 1. Split data menjadi Train (60%), Test (20%), Forward/Backtest (20%) secara berurutan (time-based split, bukan random).
# 2. Latih `RandomForestClassifier` dengan parameter hasil tuning (`rf_params_map`).
# 3. Evaluasi di data Test dan data Forward menggunakan accuracy, classification report, dan confusion matrix.
# 4. Jalankan backtest strategi trading berbasis sinyal model pada periode Forward menggunakan library `backtesting`.
# 5. Simpan hasil ringkasan performa ke `results`.

# %%
for ticker in tickers_list:

    if ticker not in processed_data:
        continue

    print(f"\n========================")
    print(f"PROCESSING {ticker}")
    print(f"========================")

    df = processed_data[ticker]

    X = df[features]
    Y = df['Label']

    total_len = len(df)
    train_idx = int(total_len * 0.60)
    test_idx = int(total_len * 0.80)

    X_train = X.iloc[:train_idx]
    Y_train = Y.iloc[:train_idx]

    X_test = X.iloc[train_idx:test_idx]
    Y_test = Y.iloc[train_idx:test_idx]

    X_forward = X.iloc[test_idx:]
    Y_forward = Y.iloc[test_idx:]

    df_forward = df.iloc[test_idx:].copy()

    print(f"Train   : {len(X_train)}")
    print(f"Test    : {len(X_test)}")
    print(f"Forward : {len(X_forward)}")

    # =====================
    # MODEL
    # =====================
    params = rf_params_map[ticker]

    rf_model = RandomForestClassifier(
        **params,
        class_weight="balanced",
        random_state=42,
        n_jobs=-1,
        max_features='sqrt'
    )

    rf_model.fit(X_train, Y_train)

    # =====================
    # PREDICTION
    # =====================
    Y_train_pred = rf_model.predict(X_train)
    Y_test_pred = rf_model.predict(X_test)
    Y_fwd_pred = rf_model.predict(X_forward)

    # =====================
    # CONFUSION MATRIX
    # =====================
    cm_test = confusion_matrix(Y_test, Y_test_pred, labels=[-1, 0, 1])
    cm_backtest = confusion_matrix(Y_forward, Y_fwd_pred, labels=[-1, 0, 1])

    testing_cms.append((ticker, cm_test))
    backtesting_cms.append((ticker, cm_backtest))

    # =====================
    # EVALUATION
    # =====================
    print(f"Test Accuracy     : {accuracy_score(Y_test, Y_test_pred):.4f}")
    print(f"Backtest Accuracy : {accuracy_score(Y_forward, Y_fwd_pred):.4f}")

    print("\nClassification Report (Test):")
    print(classification_report(Y_test, Y_test_pred))

    print("\nClassification Report (Backtest):")
    print(classification_report(Y_forward, Y_fwd_pred))

    # =====================
    # STRATEGY
    # =====================
    class RFStrategy(Strategy):

        def init(self):
            self.model = rf_model
            self.features = features

        def next(self):
            X_today = self.data.df.iloc[[-1]][self.features]
            signal = self.model.predict(X_today)[0]

            if signal == 1:
                if not self.position.is_long:
                    self.buy()
            elif signal == -1:
                if self.position.is_long:
                    self.position.close()

    # =====================
    # BACKTEST
    # =====================
    bt = Backtest(
        df_forward,
        RFStrategy,
        cash=100_000_000,
        commission=0.002,
        exclusive_orders=True,
        margin=1.0
    )

    stats = bt.run()

    print("\n=== BACKTEST RESULT ===")
    print(stats)

    # =====================
    # SAVE RESULT
    # =====================
    results.append({
        "Ticker": ticker,
        "Buy Hold Return (%)": stats["Buy & Hold Return [%]"],
        "Return (%)": stats["Return [%]"],
        "Sharpe Ratio": stats["Sharpe Ratio"],
        "Win Rate (%)": stats["Win Rate [%]"],
        "Max Drawdown (%)": stats["Max. Drawdown [%]"],
        "Jumlah Trade": stats["# Trades"],
    })
# Out:
# ========================
# PROCESSING BMHS.JK
# ========================
# Train   : 637
# Test    : 213
# Forward : 213
# Test Accuracy     : 0.4601
# Backtest Accuracy : 0.4038
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.42      0.43      0.42        74
#            0       0.51      0.47      0.49        91
#            1       0.45      0.48      0.46        48
#
#     accuracy                           0.46       213
#    macro avg       0.46      0.46      0.46       213
# weighted avg       0.46      0.46      0.46       213
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.33      0.25      0.29        71
#            0       0.57      0.54      0.56       101
#            1       0.21      0.32      0.25        41
#
#     accuracy                           0.40       213
#    macro avg       0.37      0.37      0.37       213
# weighted avg       0.42      0.40      0.41       213
# Backtest.run:   0%|          | 0/212 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2025-02-07 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    326 days 00:00:00
# Exposure Time [%]                    61.03286
# Equity Final [$]                 70865141.852
# Equity Peak [$]                 105664107.712
# Commissions [$]                    4363834.34
# Return [%]                          -29.13486
# Buy & Hold Return [%]               -20.16807
# Return (Ann.) [%]                   -33.46547
# Volatility (Ann.) [%]                13.72494
# CAGR [%]                             -23.3727
# Sharpe Ratio                          -2.4383
# Sortino Ratio                         -2.1003
# Calmar Ratio                         -0.91372
# Alpha [%]                           -25.11385
# Beta                                  0.19937
# Max. Drawdown [%]                   -36.62538
# Avg. Drawdown [%]                    -12.9625
# Max. Drawdown Duration      288 days 00:00:00
# Avg. Drawdown Duration      105 days 00:00:00
# # Trades                                   12
# Win Rate [%]                         58.33333
# Best Trade [%]                        6.48148
# Worst Trade [%]                     -22.81553
# Avg. Trade [%]                        -2.1703
# Max. Trade Duration         111 days 00:00:00
# Avg. Trade Duration          16 days 00:00:00
# Profit Factor                         0.50077
# Expectancy [%]                       -1.80706
# SQN                                  -0.79578
# Kelly Criterion                      -0.94603
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
#
# ========================
# PROCESSING DGNS.JK
# ========================
# Train   : 706
# Test    : 235
# Forward : 236
# Test Accuracy     : 0.3447
# Backtest Accuracy : 0.4958
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.38      0.27      0.31        97
#            0       0.37      0.47      0.41        72
#            1       0.29      0.32      0.30        66
#
#     accuracy                           0.34       235
#    macro avg       0.34      0.35      0.34       235
# weighted avg       0.35      0.34      0.34       235
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.47      0.23      0.31        79
#            0       0.56      0.76      0.64       105
#            1       0.35      0.37      0.36        52
#
#     accuracy                           0.50       236
#    macro avg       0.46      0.45      0.44       236
# weighted avg       0.48      0.50      0.47       236
# Backtest.run:   0%|          | 0/235 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2025-01-02 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    362 days 00:00:00
# Exposure Time [%]                    44.91525
# Equity Final [$]                118742786.986
# Equity Peak [$]                 123323491.924
# Commissions [$]                   4573446.014
# Return [%]                           18.74279
# Buy & Hold Return [%]                -6.59898
# Return (Ann.) [%]                    20.13384
# Volatility (Ann.) [%]                51.73007
# CAGR [%]                             12.70327
# Sharpe Ratio                          0.38921
# Sortino Ratio                         1.04179
# Calmar Ratio                          0.67999
# Alpha [%]                            21.57475
# Beta                                  0.42915
# Max. Drawdown [%]                   -29.60903
# Avg. Drawdown [%]                   -22.79969
# Max. Drawdown Duration      249 days 00:00:00
# Avg. Drawdown Duration      178 days 00:00:00
# # Trades                                   11
# Win Rate [%]                         63.63636
# Best Trade [%]                       26.66667
# Worst Trade [%]                     -29.32692
# Avg. Trade [%]                         1.9811
# Max. Trade Duration          71 days 00:00:00
# Avg. Trade Duration          13 days 00:00:00
# Profit Factor                         1.77599
# Expectancy [%]                        2.97588
# SQN                                   0.47384
# Kelly Criterion                       0.20898
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
#
# ========================
# PROCESSING HEAL.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.4161
# Backtest Accuracy : 0.3392
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.28      0.29      0.28        62
#            0       0.60      0.51      0.55       159
#            1       0.23      0.31      0.26        65
#
#     accuracy                           0.42       286
#    macro avg       0.37      0.37      0.37       286
# weighted avg       0.45      0.42      0.43       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.33      0.22      0.27       103
#            0       0.30      0.38      0.34        97
#            1       0.39      0.43      0.41        86
#
#     accuracy                           0.34       286
#    macro avg       0.34      0.34      0.34       286
# weighted avg       0.34      0.34      0.33       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                    69.58042
# Equity Final [$]                 100365124.26
# Equity Peak [$]                  117933203.29
# Commissions [$]                   11093895.74
# Return [%]                            0.36512
# Buy & Hold Return [%]               -11.29032
# Return (Ann.) [%]                     0.32165
# Volatility (Ann.) [%]                29.95528
# CAGR [%]                              0.20943
# Sharpe Ratio                          0.01074
# Sortino Ratio                         0.01605
# Calmar Ratio                           0.0124
# Alpha [%]                             6.99662
# Beta                                  0.58736
# Max. Drawdown [%]                   -25.93197
# Avg. Drawdown [%]                   -10.41962
# Max. Drawdown Duration      126 days 00:00:00
# Avg. Drawdown Duration       62 days 00:00:00
# # Trades                                   27
# Win Rate [%]                         48.14815
# Best Trade [%]                       21.95122
# Worst Trade [%]                       -8.7156
# Avg. Trade [%]                        0.41435
# Max. Trade Duration          29 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                         1.32517
# Expectancy [%]                        0.61482
# SQN                                   0.35192
# Kelly Criterion                       0.05571
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
#
# ========================
# PROCESSING MIKA.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.4266
# Backtest Accuracy : 0.3986
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.29      0.34      0.32        67
#            0       0.51      0.58      0.54       145
#            1       0.36      0.20      0.26        74
#
#     accuracy                           0.43       286
#    macro avg       0.39      0.38      0.37       286
# weighted avg       0.42      0.43      0.42       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.60      0.17      0.27       103
#            0       0.39      0.60      0.48       106
#            1       0.34      0.42      0.38        77
#
#     accuracy                           0.40       286
#    macro avg       0.45      0.40      0.37       286
# weighted avg       0.45      0.40      0.38       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                    74.12587
# Equity Final [$]                 100371767.56
# Equity Peak [$]                  120644863.88
# Commissions [$]                     7191185.5
# Return [%]                            0.37177
# Buy & Hold Return [%]               -22.97735
# Return (Ann.) [%]                      0.3275
# Volatility (Ann.) [%]                32.98996
# CAGR [%]                              0.21324
# Sharpe Ratio                          0.00993
# Sortino Ratio                         0.01517
# Calmar Ratio                          0.01632
# Alpha [%]                            16.51392
# Beta                                  0.70252
# Max. Drawdown [%]                   -20.06682
# Avg. Drawdown [%]                     -9.9478
# Max. Drawdown Duration      181 days 00:00:00
# Avg. Drawdown Duration       61 days 00:00:00
# # Trades                                   18
# Win Rate [%]                             50.0
# Best Trade [%]                       12.85141
# Worst Trade [%]                         -12.8
# Avg. Trade [%]                        0.45606
# Max. Trade Duration          46 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                         1.29353
# Expectancy [%]                        0.65721
# SQN                                   0.29114
# Kelly Criterion                       0.02893
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
#
# ========================
# PROCESSING PRDA.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.3427
# Backtest Accuracy : 0.4615
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.40      0.26      0.32       110
#            0       0.47      0.45      0.46       127
#            1       0.13      0.24      0.17        49
#
#     accuracy                           0.34       286
#    macro avg       0.34      0.32      0.32       286
# weighted avg       0.39      0.34      0.36       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.34      0.28      0.30        80
#            0       0.55      0.72      0.62       145
#            1       0.17      0.08      0.11        61
#
#     accuracy                           0.46       286
#    macro avg       0.35      0.36      0.35       286
# weighted avg       0.41      0.46      0.43       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                    37.76224
# Equity Final [$]                 100965675.58
# Equity Peak [$]                  101168011.28
# Commissions [$]                    2723314.42
# Return [%]                            0.96568
# Buy & Hold Return [%]               -24.59016
# Return (Ann.) [%]                     0.85039
# Volatility (Ann.) [%]                11.21621
# CAGR [%]                              0.55319
# Sharpe Ratio                          0.07582
# Sortino Ratio                         0.11228
# Calmar Ratio                          0.08211
# Alpha [%]                               6.595
# Beta                                  0.22893
# Max. Drawdown [%]                   -10.35702
# Avg. Drawdown [%]                    -4.81764
# Max. Drawdown Duration      323 days 00:00:00
# Avg. Drawdown Duration      122 days 00:00:00
# # Trades                                    7
# Win Rate [%]                         71.42857
# Best Trade [%]                        4.38247
# Worst Trade [%]                      -6.47482
# Avg. Trade [%]                        0.53873
# Max. Trade Duration          84 days 00:00:00
# Avg. Trade Duration          23 days 00:00:00
# Profit Factor                         1.50983
# Expectancy [%]                        0.59935
# SQN                                   0.38223
# Kelly Criterion                       0.22212
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
#
# ========================
# PROCESSING PRIM.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.2972
# Backtest Accuracy : 0.3147
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.37      0.43      0.40       126
#            0       0.30      0.22      0.25        78
#            1       0.17      0.17      0.17        82
#
#     accuracy                           0.30       286
#    macro avg       0.28      0.27      0.27       286
# weighted avg       0.29      0.30      0.29       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.35      0.56      0.43       101
#            0       0.18      0.17      0.18        82
#            1       0.42      0.18      0.26       103
#
#     accuracy                           0.31       286
#    macro avg       0.32      0.31      0.29       286
# weighted avg       0.33      0.31      0.29       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                    27.27273
# Equity Final [$]                180968579.856
# Equity Peak [$]                 180968579.856
# Commissions [$]                  14236699.728
# Return [%]                           80.96858
# Buy & Hold Return [%]                33.87097
# Return (Ann.) [%]                    68.64716
# Volatility (Ann.) [%]                68.87088
# CAGR [%]                             40.56346
# Sharpe Ratio                          0.99675
# Sortino Ratio                         6.76026
# Calmar Ratio                           4.8624
# Alpha [%]                            63.73327
# Beta                                  0.50885
# Max. Drawdown [%]                   -14.11797
# Avg. Drawdown [%]                    -3.75401
# Max. Drawdown Duration      219 days 00:00:00
# Avg. Drawdown Duration       40 days 00:00:00
# # Trades                                   26
# Win Rate [%]                         61.53846
# Best Trade [%]                        57.8125
# Worst Trade [%]                      -7.35294
# Avg. Trade [%]                        2.67765
# Max. Trade Duration          10 days 00:00:00
# Avg. Trade Duration           3 days 00:00:00
# Profit Factor                         5.67383
# Expectancy [%]                        3.15597
# SQN                                   1.48804
# Kelly Criterion                       0.36878
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                          Size  Ent...
# dtype: object
#
# ========================
# PROCESSING SAME.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.4021
# Backtest Accuracy : 0.3462
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.44      0.44      0.44       101
#            0       0.38      0.42      0.40       103
#            1       0.39      0.34      0.36        82
#
#     accuracy                           0.40       286
#    macro avg       0.40      0.40      0.40       286
# weighted avg       0.40      0.40      0.40       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.35      0.40      0.37       105
#            0       0.40      0.29      0.34       107
#            1       0.30      0.35      0.32        74
#
#     accuracy                           0.35       286
#    macro avg       0.35      0.35      0.34       286
# weighted avg       0.35      0.35      0.35       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                    41.25874
# Equity Final [$]                  97526190.36
# Equity Peak [$]                 114888419.512
# Commissions [$]                   7733451.524
# Return [%]                           -2.47381
# Buy & Hold Return [%]                27.46479
# Return (Ann.) [%]                    -2.18296
# Volatility (Ann.) [%]                34.87071
# CAGR [%]                             -1.42762
# Sharpe Ratio                          -0.0626
# Sortino Ratio                        -0.10323
# Calmar Ratio                         -0.11594
# Alpha [%]                           -14.52688
# Beta                                  0.43886
# Max. Drawdown [%]                   -18.82838
# Avg. Drawdown [%]                   -15.01215
# Max. Drawdown Duration      237 days 00:00:00
# Avg. Drawdown Duration      132 days 00:00:00
# # Trades                                   19
# Win Rate [%]                         36.84211
# Best Trade [%]                        18.9781
# Worst Trade [%]                     -13.25967
# Avg. Trade [%]                        0.27907
# Max. Trade Duration          39 days 00:00:00
# Avg. Trade Duration           9 days 00:00:00
# Profit Factor                         1.22182
# Expectancy [%]                        0.55581
# SQN                                   0.15908
# Kelly Criterion                      -0.03108
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                         Size  Entr...
# dtype: object
#
# ========================
# PROCESSING SILO.JK
# ========================
# Train   : 856
# Test    : 286
# Forward : 286
# Test Accuracy     : 0.3531
# Backtest Accuracy : 0.4685
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#           -1       0.23      0.17      0.20        81
#            0       0.45      0.46      0.46       102
#            1       0.33      0.39      0.36       103
#
#     accuracy                           0.35       286
#    macro avg       0.34      0.34      0.34       286
# weighted avg       0.35      0.35      0.35       286
#
#
# Classification Report (Backtest):
#               precision    recall  f1-score   support
#
#           -1       0.37      0.30      0.33        87
#            0       0.58      0.61      0.59       136
#            1       0.35      0.40      0.37        63
#
#     accuracy                           0.47       286
#    macro avg       0.43      0.44      0.43       286
# weighted avg       0.46      0.47      0.46       286
# Backtest.run:   0%|          | 0/285 [00:00<?, ?bar/s]
# === BACKTEST RESULT ===
# Start                     2024-10-17 00:00:00
# End                       2025-12-30 00:00:00
# Duration                    439 days 00:00:00
# Exposure Time [%]                     54.1958
# Equity Final [$]                 105045661.96
# Equity Peak [$]                  105519561.94
# Commissions [$]                    6883779.12
# Return [%]                            5.04566
# Buy & Hold Return [%]               -12.17949
# Return (Ann.) [%]                     4.43274
# Volatility (Ann.) [%]                28.77878
# CAGR [%]                              2.86597
# Sharpe Ratio                          0.15403
# Sortino Ratio                         0.26025
# Calmar Ratio                          0.12667
# Alpha [%]                             9.71242
# Beta                                  0.38317
# Max. Drawdown [%]                   -34.99464
# Avg. Drawdown [%]                   -15.16317
# Max. Drawdown Duration      365 days 00:00:00
# Avg. Drawdown Duration      141 days 00:00:00
# # Trades                                   21
# Win Rate [%]                         38.09524
# Best Trade [%]                        35.6383
# Worst Trade [%]                      -10.4918
# Avg. Trade [%]                        0.35804
# Max. Trade Duration          50 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                         1.33266
# Expectancy [%]                         0.7143
# SQN                                   0.18503
# Kelly Criterion                      -0.00905
# _strategy                          RFStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ## 10. Visualisasi Confusion Matrix
#
# Fungsi untuk menampilkan 4 confusion matrix sekaligus dalam satu gambar (grid 2x2), dipakai untuk
# membandingkan performa Testing dan Backtesting antar kelompok ticker.

# %%
def plot_group_confusion_matrix(cm_list, title, filename):

    fig, axes = plt.subplots(2, 2, figsize=(14, 12))
    axes = axes.flatten()

    for ax, (ticker, cm) in zip(axes, cm_list):
        sns.heatmap(
            cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=labels,
            yticklabels=labels,
            ax=ax
        )
        ax.set_title(ticker, fontsize=12)
        ax.set_xlabel("Predicted")
        ax.set_ylabel("Actual")

    plt.suptitle(title, fontsize=18, fontweight='bold')
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.savefig(filename, dpi=300)
    plt.show()

# %% [markdown]
# ### 10.1 Confusion Matrix - Testing (Ticker 1-4 dan 5-8)

# %%
plot_group_confusion_matrix(
    testing_cms[:4],
    "Testing Confusion Matrix (1-4)",
    "testing_confusion_matrix_1.png"
)

plot_group_confusion_matrix(
    testing_cms[4:8],
    "Testing Confusion Matrix (5-8)",
    "testing_confusion_matrix_2.png"
)

# %% [markdown]
# ### 10.2 Confusion Matrix - Backtesting (Ticker 1-4 dan 5-8)

# %%
plot_group_confusion_matrix(
    backtesting_cms[:4],
    "Backtesting Confusion Matrix (1-4)",
    "backtesting_confusion_matrix_1.png"
)

plot_group_confusion_matrix(
    backtesting_cms[4:8],
    "Backtesting Confusion Matrix (5-8)",
    "backtesting_confusion_matrix_2.png"
)

# %% [markdown]
# ## 11. Ringkasan Hasil Backtest Seluruh Ticker
#
# Menampilkan tabel ringkasan performa (Return, Buy & Hold Return, Sharpe Ratio, Win Rate, Max Drawdown,
# Jumlah Trade) untuk seluruh ticker dalam satu tabel agar mudah dibandingkan.

# %%
results_df = pd.DataFrame(results)

print("==============================")
print("=== HASIL BACKTEST SEMUA TICKER ===")
print("==============================")

results_df
# Out:
# ==============================
# === HASIL BACKTEST SEMUA TICKER ===
# ==============================
#     Ticker  Buy Hold Return (%)  Return (%)  Sharpe Ratio  Win Rate (%)  \
# 0  BMHS.JK           -20.168067  -29.134858     -2.438297     58.333333
# 1  DGNS.JK            -6.598985   18.742787      0.389210     63.636364
# 2  HEAL.JK           -11.290323    0.365124      0.010738     48.148148
# 3  MIKA.JK           -22.977346    0.371768      0.009927     50.000000
# 4  PRDA.JK           -24.590164    0.965676      0.075818     71.428571
# 5  PRIM.JK            33.870968   80.968580      0.996752     61.538462
# 6  SAME.JK            27.464789   -2.473810     -0.062601     36.842105
# 7  SILO.JK           -12.179487    5.045662      0.154028     38.095238
#
#    Max Drawdown (%)  Jumlah Trade
# 0        -36.625377            12
# 1        -29.609031            11
# 2        -25.931973            27
# 3        -20.066819            18
# 4        -10.357021             7
# 5        -14.117968            26
# 6        -18.828382            19
# 7        -34.994642            21
